# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# `DATASET` <br>Percentage of Schools with Drinking Water Facility from 2013-14 to 2015-16 <br>https://data.gov.in/resource/percentage-schools-drinking-water-facility-2013-14-2015-16

# %%
data = pd.read_csv('schools_with_water_1.csv')
data.head()
# Out:
#                     State/UT     Year  Primary_Only  Primary_with_U_Primary  \
# 0  Andaman & Nicobar Islands  2013-14         98.17                   98.68
# 1  Andaman & Nicobar Islands  2014-15         99.55                   98.77
# 2  Andaman & Nicobar Islands  2015-16        100.00                  100.00
# 3             Andhra Pradesh  2013-14         86.89                   94.53
# 4             Andhra Pradesh  2014-15         91.85                   96.07
#
#    Primary_with_U_Primary_Sec_HrSec  U_Primary_Only  U_Primary_With_Sec_HrSec  \
# 0                            100.00            0.00                    100.00
# 1                            100.00          100.00                    100.00
# 2                            100.00            0.00                    100.00
# 3                             99.66           90.91                     87.26
# 4                            100.00          100.00                     90.00
#
# ...

# %% [markdown]
# `EDA`

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   State/UT                          110 non-null    object
#  1   Year                              110 non-null    object
#  2   Primary_Only                      110 non-null    float64
#  3   Primary_with_U_Primary            110 non-null    float64
#  4   Primary_with_U_Primary_Sec_HrSec  110 non-null    float64
#  5   U_Primary_Only                    110 non-null    float64
#  6   U_Primary_With_Sec_HrSec          110 non-null    float64
#  7   Primary_with_U_Primary_Sec        110 non-null    float64
#  8   U_Primary_With_Sec                110 non-null    float64
#  9   Sec_Only                          110 non-null    float64
#  10  Sec_with_HrSec.                   110 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# State/UT                            0
# Year                                0
# Primary_Only                        0
# Primary_with_U_Primary              0
# Primary_with_U_Primary_Sec_HrSec    0
# U_Primary_Only                      0
# U_Primary_With_Sec_HrSec            0
# Primary_with_U_Primary_Sec          0
# U_Primary_With_Sec                  0
# Sec_Only                            0
# Sec_with_HrSec.                     0
# HrSec_Only                          0
# All Schools                         0
# dtype: int64

# %%
data.describe()
# Out:
#        Primary_Only  Primary_with_U_Primary  Primary_with_U_Primary_Sec_HrSec  \
# count    110.000000              110.000000                        110.000000
# mean      93.726091               96.522545                         97.193727
# std        9.095579                7.098145                         13.594592
# min       61.040000               59.400000                          0.000000
# 25%       90.430000               95.972500                         99.205000
# 50%       98.085000               99.225000                        100.000000
# 75%       99.857500              100.000000                        100.000000
# max      100.000000              100.000000                        100.000000
#
#        U_Primary_Only  U_Primary_With_Sec_HrSec  Primary_with_U_Primary_Sec  \
# count      110.000000                110.000000                  110.000000
# mean        89.125636                 95.271818                   92.248818
# ...

# %%
sns.histplot(data=data, x="Primary_Only", kde=True)

# %%
sns.histplot(data=data, x="Primary_with_U_Primary", kde=True)

# %%
sns.histplot(data=data, x="All Schools", kde=True)

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4d6e5c3d60>,
# ...
#       dtype=object)

# %%
sns.pairplot(data)

# %% [markdown]
# <br> 1) The provision of water at schools is one of the ‘highly effective practices in increasing access and learning outcomes’. In addition to the necessity of water to maintain personal and environmental hygiene, reducing student dehydration in schools has been associated with improved cognitive abilities. Globally, in 2016, 69% of schools had an improved source of drinking water with water available and were therefore classified as providing a basic drinking water service. </br>
# <br> 2) This dataset provides the Percentage of Schools with Drinking Water Facility from 2013-14 to 2015-16.</br>
# <br> 3) Their is no basic drinking water service in many schools as seen in the dataset.</br>
# <br> 4) Also as the years progress we can see that their is an increse in the percentage of schools with drinking water facility. </br>
# <br> 5) This dataset can provide us the inputs on whether thier has been any increase in the drinking water facility in schools which can be very helpful in our society.  </br>

# %% [markdown]
# `Normalization`

# %%
data.iloc[9]
# Out:
# State/UT                              Assam
# Year                                2013-14
# Primary_Only                          78.32
# Primary_with_U_Primary                91.18
# Primary_with_U_Primary_Sec_HrSec       95.9
# U_Primary_Only                        79.55
# U_Primary_With_Sec_HrSec              97.01
# Primary_with_U_Primary_Sec            93.25
# U_Primary_With_Sec                    93.46
# Sec_Only                               88.3
# Sec_with_HrSec.                        88.6
# HrSec_Only                            96.22
# All Schools                            80.3
# Name: 9, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
norm = MinMaxScaler()
# transform data
data_norm = norm.fit_transform(data.select_dtypes(exclude = ['object']))
data_norm
# Out:
# array([[0.95302875, 0.96748768, 1.        , ..., 1.        , 0.        ,
#         0.96574268],
#        [0.98844969, 0.96970443, 1.        , ..., 1.        , 0.        ,
#         0.9874477 ],
#        [1.        , 1.        , 1.        , ..., 1.        , 0.        ,
#         1.        ],
#        ...,
#        [0.84830595, 0.95517241, 0.991     , ..., 0.9818    , 0.9714    ,
#         0.87970711],
#        [0.86858316, 0.96280788, 0.9959    , ..., 0.9871    , 0.9823    ,
#         0.89853556],
#        [0.89168378, 0.96773399, 0.9939    , ..., 0.9918    , 0.9792    ,
#         0.9165795 ]])

# %%
data_norm[9]
# Out:
# array([0.44353183, 0.78275862, 0.959     , 0.7955    , 0.9701    ,
#        0.9325    , 0.9346    , 0.883     , 0.886     , 0.9622    ,
#        0.48483264])

# %% [markdown]
# `Standardization`

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data.select_dtypes(exclude = ['object']))
data_scaled
# Out:
# array([[ 0.49081512,  0.30533732,  0.20737041, ...,  0.53438273,
#         -2.07682475,  0.4814757 ],
#        [ 0.64323157,  0.31807472,  0.20737041, ...,  0.53438273,
#         -2.07682475,  0.58762031],
#        [ 0.69293259,  0.49215251,  0.20737041, ...,  0.53438273,
#         -2.07682475,  0.64900515],
#        ...,
#        [ 0.04019256,  0.234574  ,  0.14086463, ...,  0.48552382,
#          0.47695155,  0.06073379],
#        [ 0.12744546,  0.27844726,  0.17707333, ...,  0.49975196,
#          0.50560727,  0.15281104],
#        [ 0.22684749,  0.30675259,  0.16229427, ...,  0.51236937,
#          0.49745748,  0.24105175]])

# %%
data_scaled[9]
# Out:
# array([-1.70155198, -0.75611258, -0.09560039, -0.38123488,  0.10528095,
#         0.0413757 ,  0.34573378,  0.50351322,  0.22834341,  0.45276508,
#        -1.8703309 ])
